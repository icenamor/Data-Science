# %% [markdown]
# # Exercise 02 -  OLAP Cubes - CUBE

# %% [markdown]
# All the databases table in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)
#
# Start by connecting to the database by running the cells below. If you are coming back to this exercise, then uncomment and run the first cell to recreate the database. If you recently completed the slicing and dicing exercise, then skip to the second cell.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # CUBE
# - Group by CUBE (dim1, dim2, ..) , produces all combinations of different lenghts in one go.
# - This view could be materialized in a view and queried which would save lots repetitive aggregations

# %% [markdown]
# TODO: Write a query that calculates the various levels of aggregation done in the grouping sets exercise (total, by month, by country, by month & country) using the CUBE function. Your output should match the table below.

# %%
# %%time
# %%sql
SELECT dimDate.month, dimCustomer.country, sum(sales_amount) as revenue
FROM factSales
JOIN dimDate ON (dimDate.date_key =  factSales.date_key)
JOIN dimCustomer ON (dimCustomer.customer_key = factSales.customer_key)
GROUP BY cube(dimDate.month, dimCustomer.country);
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 598 rows affected.
# CPU times: user 5.03 ms, sys: 180 µs, total: 5.21 ms
# Wall time: 40.7 ms
# [(1, 'Algeria', Decimal('33.92')),
#  (1, 'Angola', Decimal('27.93')),
#  (1, 'Anguilla', Decimal('6.97')),
#  (1, 'Argentina', Decimal('81.78')),
#  (1, 'Austria', Decimal('22.92')),
#  (1, 'Azerbaijan', Decimal('20.97')),
#  (1, 'Bahrain', Decimal('3.99')),
#  (1, 'Bangladesh', Decimal('19.95')),
#  (1, 'Belarus', Decimal('5.98')),
#  (1, 'Bolivia', Decimal('4.97')),
#  (1, 'Brazil', Decimal('210.50')),
#  (1, 'Brunei', Decimal('5.99')),
#  (1, 'Bulgaria', Decimal('9.98')),
#  (1, 'Cambodia', Decimal('11.96')),
#  (1, 'Cameroon', Decimal('13.97')),
#  (1, 'Canada', Decimal('33.93')),
#  (1, 'Chad', Decimal('12.96')),
#  (1, 'Chile', Decimal('24.95')),
#  (1, 'China', Decimal('455.91')),
#  (1, 'Colombia', Decimal('47.87')),
#  (1, 'Congo, The Democratic Republic of the', Decimal('43.92')),
#  (1, 'Czech Republic', Decimal('0.99')),
#  (1, 'Dominican Republic', Decimal('13.97')),
#  (1, 'Ecuador', Decimal('20.95')),
#  (1, 'Egypt', Decimal('34.91')),
#  (1, 'Estonia', Decimal('9.98')),
#  (1, 'Faroe Islands', Decimal('6.99')),
#  (1, 'Finland', Decimal('3.99')),
#  (1, 'France', Decimal('39.92')),
#  (1, 'French Guiana', Decimal('5.98')),
#  (1, 'French Polynesia', Decimal('29.94')),
#  (1, 'Gambia', Decimal('14.97')),
#  (1, 'Germany', Decimal('89.80')),
#  (1, 'Greece', Decimal('27.92')),
#  (1, 'Greenland', Decimal('17.94')),
#  (1, 'Holy See (Vatican City State)', Decimal('5.98')),
#  (1, 'India', Decimal('429.89')),
#  (1, 'Indonesia', Decimal('135.69')),
#  (1, 'Iran', Decimal('55.84')),
#  (1, 'Israel', Decimal('39.89')),
#  (1, 'Italy', Decimal('51.89')),
#  (1, 'Japan', Decimal('288.35')),
#  (1, 'Kazakstan', Decimal('5.97')),
#  (1, 'Kenya', Decimal('7.97')),
#  (1, 'Kuwait', Decimal('4.99')),
#  (1, 'Latvia', Decimal('12.97')),
#  (1, 'Liechtenstein', Decimal('14.98')),
#  (1, 'Lithuania', Decimal('9.98')),
#  (1, 'Madagascar', Decimal('0.99')),
#  (1, 'Malawi', Decimal('1.99')),
#  (1, 'Malaysia', Decimal('30.94')),
#  (1, 'Mexico', Decimal('263.37')),
#  (1, 'Morocco', Decimal('32.94')),
#  (1, 'Mozambique', Decimal('28.95')),
#  (1, 'Myanmar', Decimal('14.95')),
#  (1, 'Nauru', Decimal('4.99')),
#  (1, 'Nepal', Decimal('15.97')),
#  (1, 'Netherlands', Decimal('25.94')),
#  (1, 'New Zealand', Decimal('6.99')),
#  (1, 'Nigeria', Decimal('134.71')),
#  (1, 'North Korea', Decimal('5.98')),
#  (1, 'Oman', Decimal('25.94')),
#  (1, 'Pakistan', Decimal('51.88')),
#  (1, 'Paraguay', Decimal('1.98')),
#  (1, 'Peru', Decimal('40.91')),
#  (1, 'Philippines', Decimal('161.62')),
#  (1, 'Poland', Decimal('54.89')),
#  (1, 'Puerto Rico', Decimal('15.95')),
#  (1, 'Romania', Decimal('16.96')),
#  (1, 'Runion', Decimal('4.99')),
#  (1, 'Russian Federation', Decimal('225.40')),
#  (1, 'Saint Vincent and the Grenadines', Decimal('15.97')),
#  (1, 'Saudi Arabia', Decimal('65.87')),
#  (1, 'Senegal', Decimal('4.99')),
#  (1, 'Slovakia', Decimal('8.97')),
#  (1, 'South Africa', Decimal('99.76')),
#  (1, 'South Korea', Decimal('46.88')),
#  (1, 'Spain', Decimal('56.85')),
#  (1, 'Sri Lanka', Decimal('12.97')),
#  (1, 'Sudan', Decimal('24.95')),
#  (1, 'Sweden', Decimal('4.99')),
#  (1, 'Switzerland', Decimal('3.98')),
#  (1, 'Taiwan', Decimal('55.84')),
#  (1, 'Tanzania', Decimal('18.95')),
#  (1, 'Thailand', Decimal('17.96')),
#  (1, 'Tonga', Decimal('8.98')),
#  (1, 'Turkey', Decimal('120.73')),
#  (1, 'Turkmenistan', Decimal('9.99')),
#  (1, 'Tuvalu', Decimal('26.96')),
#  (1, 'Ukraine', Decimal('54.89')),
#  (1, 'United Arab Emirates', Decimal('12.95')),
#  (1, 'United Kingdom', Decimal('73.84')),
#  (1, 'United States', Decimal('309.30')),
#  (1, 'Venezuela', Decimal('24.92')),
#  (1, 'Vietnam', Decimal('33.91')),
#  (1, 'Virgin Islands, U.S.', Decimal('0.99')),
#  (1, 'Yemen', Decimal('15.94')),
#  (1, 'Yugoslavia', Decimal('25.94')),
#  (1, 'Zambia', Decimal('12.97')),
#  (1, None, Decimal('4824.43')),
#  (2, 'Afghanistan', Decimal('4.97')),
#  (2, 'Algeria', Decimal('60.88')),
#  (2, 'American Samoa', Decimal('23.95')),
#  (2, 'Angola', Decimal('35.92')),
#  (2, 'Anguilla', Decimal('16.95')),
#  (2, 'Argentina', Decimal('219.49')),
#  (2, 'Armenia', Decimal('12.98')),
#  (2, 'Austria', Decimal('39.89')),
#  (2, 'Azerbaijan', Decimal('25.93')),
#  (2, 'Bahrain', Decimal('30.95')),
#  (2, 'Bangladesh', Decimal('60.86')),
#  (2, 'Belarus', Decimal('30.90')),
#  (2, 'Bolivia', Decimal('43.89')),
#  (2, 'Brazil', Decimal('454.87')),
#  (2, 'Brunei', Decimal('12.96')),
#  (2, 'Bulgaria', Decimal('42.89')),
#  (2, 'Cambodia', Decimal('36.90')),
#  (2, 'Cameroon', Decimal('33.91')),
#  (2, 'Canada', Decimal('75.80')),
#  (2, 'Chad', Decimal('9.98')),
#  (2, 'Chile', Decimal('51.87')),
#  (2, 'China', Decimal('839.02')),
#  (2, 'Colombia', Decimal('72.83')),
#  (2, 'Congo, The Democratic Republic of the', Decimal('28.91')),
#  (2, 'Czech Republic', Decimal('15.97')),
#  (2, 'Dominican Republic', Decimal('33.91')),
#  (2, 'Ecuador', Decimal('54.90')),
#  (2, 'Egypt', Decimal('121.73')),
#  (2, 'Estonia', Decimal('25.94')),
#  (2, 'Ethiopia', Decimal('17.96')),
#  (2, 'Faroe Islands', Decimal('10.97')),
#  (2, 'Finland', Decimal('18.96')),
#  (2, 'France', Decimal('52.82')),
#  (2, 'French Guiana', Decimal('12.98')),
#  (2, 'French Polynesia', Decimal('18.95')),
#  (2, 'Gambia', Decimal('10.98')),
#  (2, 'Germany', Decimal('133.71')),
#  (2, 'Greece', Decimal('29.94')),
#  (2, 'Greenland', Decimal('3.99')),
#  (2, 'Holy See (Vatican City State)', Decimal('41.93')),
#  (2, 'Hong Kong', Decimal('37.94')),
#  (2, 'Hungary', Decimal('24.95')),
#  (2, 'India', Decimal('832.92')),
#  (2, 'Indonesia', Decimal('239.42')),
#  (2, 'Iran', Decimal('129.65')),
#  (2, 'Iraq', Decimal('12.97')),
#  (2, 'Israel', Decimal('53.89')),
#  (2, 'Italy', Decimal('121.76')),
#  (2, 'Japan', Decimal('488.83')),
#  (2, 'Kazakstan', Decimal('33.90')),
#  (2, 'Kenya', Decimal('58.89')),
#  (2, 'Kuwait', Decimal('36.92')),
#  (2, 'Latvia', Decimal('48.90')),
#  (2, 'Liechtenstein', Decimal('20.95')),
#  (2, 'Lithuania', Decimal('11.97')),
#  (2, 'Madagascar', Decimal('12.97')),
#  (2, 'Malawi', Decimal('13.96')),
#  (2, 'Malaysia', Decimal('47.88')),
#  (2, 'Mexico', Decimal('504.83')),
#  (2, 'Moldova', Decimal('15.95')),
#  (2, 'Morocco', Decimal('41.90')),
#  (2, 'Mozambique', Decimal('14.95')),
#  (2, 'Myanmar', Decimal('47.87')),
#  (2, 'Nauru', Decimal('12.97')),
#  (2, 'Nepal', Decimal('6.98')),
#  (2, 'Netherlands', Decimal('86.83')),
#  (2, 'New Zealand', Decimal('13.97')),
#  (2, 'Nigeria', Decimal('177.60')),
#  (2, 'North Korea', Decimal('0.99')),
#  (2, 'Oman', Decimal('32.92')),
#  (2, 'Pakistan', Decimal('81.81')),
#  (2, 'Paraguay', Decimal('34.90')),
#  (2, 'Peru', Decimal('71.83')),
#  (2, 'Philippines', Decimal('359.17')),
#  (2, 'Poland', Decimal('161.66')),
#  (2, 'Puerto Rico', Decimal('32.92')),
#  (2, 'Romania', Decimal('26.92')),
#  (2, 'Runion', Decimal('22.95')),
#  (2, 'Russian Federation', Decimal('425.94')),
#  (2, 'Saint Vincent and the Grenadines', Decimal('15.96')),
#  (2, 'Saudi Arabia', Decimal('37.91')),
#  (2, 'Senegal', Decimal('25.93')),
#  (2, 'Slovakia', Decimal('16.96')),
#  (2, 'South Africa', Decimal('177.58')),
#  (2, 'South Korea', Decimal('54.84')),
#  (2, 'Spain', Decimal('68.85')),
#  (2, 'Sri Lanka', Decimal('10.97')),
#  (2, 'Sudan', Decimal('27.90')),
#  (2, 'Sweden', Decimal('29.93')),
#  (2, 'Switzerland', Decimal('30.94')),
#  (2, 'Taiwan', Decimal('171.60')),
#  (2, 'Tanzania', Decimal('34.90')),
#  (2, 'Thailand', Decimal('63.84')),
#  (2, 'Tonga', Decimal('9.97')),
#  (2, 'Tunisia', Decimal('4.99')),
#  (2, 'Turkey', Decimal('206.48')),
#  (2, 'Turkmenistan', Decimal('31.93')),
#  (2, 'Tuvalu', Decimal('11.97')),
#  (2, 'Ukraine', Decimal('79.80')),
#  (2, 'United Arab Emirates', Decimal('63.83')),
#  (2, 'United Kingdom', Decimal('182.62')),
#  (2, 'United States', Decimal('590.48')),
#  (2, 'Venezuela', Decimal('140.68')),
#  (2, 'Vietnam', Decimal('116.74')),
#  (2, 'Virgin Islands, U.S.', Decimal('26.93')),
#  (2, 'Yemen', Decimal('70.82')),
#  (2, 'Yugoslavia', Decimal('30.92')),
#  (2, 'Zambia', Decimal('17.94')),
#  (2, None, Decimal('9631.88')),
#  (3, 'Afghanistan', Decimal('24.93')),
#  (3, 'Algeria', Decimal('111.72')),
#  (3, 'American Samoa', Decimal('7.96')),
#  (3, 'Angola', Decimal('67.83')),
#  (3, 'Anguilla', Decimal('44.87')),
#  (3, 'Argentina', Decimal('455.90')),
#  (3, 'Armenia', Decimal('31.93')),
#  (3, 'Austria', Decimal('126.70')),
#  (3, 'Azerbaijan', Decimal('87.79')),
#  (3, 'Bahrain', Decimal('17.96')),
#  (3, 'Bangladesh', Decimal('154.64')),
#  (3, 'Belarus', Decimal('116.74')),
#  (3, 'Bolivia', Decimal('67.82')),
#  (3, 'Brazil', Decimal('1106.43')),
#  (3, 'Brunei', Decimal('29.90')),
#  (3, 'Bulgaria', Decimal('78.80')),
#  (3, 'Cambodia', Decimal('30.89')),
#  (3, 'Cameroon', Decimal('71.80')),
#  (3, 'Canada', Decimal('259.48')),
#  (3, 'Chad', Decimal('63.85')),
#  (3, 'Chile', Decimal('149.70')),
#  (3, 'China', Decimal('2061.94')),
#  (3, 'Colombia', Decimal('252.46')),
#  (3, 'Congo, The Democratic Republic of the', Decimal('94.77')),
#  (3, 'Czech Republic', Decimal('45.91')),
#  (3, 'Dominican Republic', Decimal('134.65')),
#  (3, 'Ecuador', Decimal('147.67')),
#  (3, 'Egypt', Decimal('256.40')),
#  (3, 'Estonia', Decimal('51.86')),
#  (3, 'Ethiopia', Decimal('49.89')),
#  (3, 'Faroe Islands', Decimal('44.89')),
#  (3, 'Finland', Decimal('45.89')),
#  (3, 'France', Decimal('80.76')),
#  (3, 'French Guiana', Decimal('46.91')),
#  (3, 'French Polynesia', Decimal('91.81')),
#  (3, 'Gambia', Decimal('58.87')),
#  (3, 'Germany', Decimal('266.37')),
#  (3, 'Greece', Decimal('82.80')),
#  (3, 'Greenland', Decimal('56.88')),
#  (3, 'Holy See (Vatican City State)', Decimal('57.88')),
#  (3, 'Hong Kong', Decimal('54.88')),
#  (3, 'Hungary', Decimal('23.92')),
#  (3, 'India', Decimal('2547.23')),
#  (3, 'Indonesia', Decimal('522.63')),
#  (3, 'Iran', Decimal('350.22')),
#  (3, 'Iraq', Decimal('31.91')),
#  (3, 'Israel', Decimal('121.70')),
#  (3, 'Italy', Decimal('314.26')),
#  (3, 'Japan', Decimal('1253.03')),
#  (3, 'Kazakstan', Decimal('61.85')),
#  (3, 'Kenya', Decimal('85.82')),
#  (3, 'Kuwait', Decimal('53.87')),
#  (3, 'Latvia', Decimal('70.84')),
#  (3, 'Liechtenstein', Decimal('28.94')),
#  (3, 'Lithuania', Decimal('19.92')),
#  (3, 'Madagascar', Decimal('55.88')),
#  (3, 'Malawi', Decimal('50.90')),
#  (3, 'Malaysia', Decimal('155.67')),
#  (3, 'Mexico', Decimal('1138.11')),
#  (3, 'Moldova', Decimal('45.89')),
#  (3, 'Morocco', Decimal('126.72')),
#  (3, 'Mozambique', Decimal('104.74')),
#  (3, 'Myanmar', Decimal('96.77')),
#  (3, 'Nauru', Decimal('69.86')),
#  (3, 'Nepal', Decimal('42.93')),
#  (3, 'Netherlands', Decimal('236.46')),
#  (3, 'New Zealand', Decimal('35.92')),
#  (3, 'Nigeria', Decimal('542.77')),
#  (3, 'North Korea', Decimal('48.90')),
#  (3, 'Oman', Decimal('42.89')),
#  (3, 'Pakistan', Decimal('208.50')),
#  (3, 'Paraguay', Decimal('91.78')),
#  (3, 'Peru', Decimal('173.61')),
#  (3, 'Philippines', Decimal('905.98')),
#  (3, 'Poland', Decimal('272.30')),
#  (3, 'Puerto Rico', Decimal('69.85')),
#  (3, 'Romania', Decimal('71.81')),
#  (3, 'Runion', Decimal('87.82')),
#  (3, 'Russian Federation', Decimal('959.68')),
#  (3, 'Saint Vincent and the Grenadines', Decimal('17.94')),
#  (3, 'Saudi Arabia', Decimal('179.54')),
#  (3, 'Senegal', Decimal('44.90')),
#  (3, 'Slovakia', Decimal('20.93')),
#  (3, 'South Africa', Decimal('453.98')),
#  (3, 'South Korea', Decimal('177.64')),
#  (3, 'Spain', Decimal('213.49')),
#  (3, 'Sri Lanka', Decimal('46.88')),
#  (3, 'Sudan', Decimal('68.85')),
#  (3, 'Sweden', Decimal('48.87')),
#  (3, 'Switzerland', Decimal('68.81')),
#  (3, 'Taiwan', Decimal('398.94')),
#  (3, 'Tanzania', Decimal('136.65')),
#  (3, 'Thailand', Decimal('147.68')),
#  (3, 'Tonga', Decimal('25.93')),
#  (3, 'Tunisia', Decimal('16.94')),
#  (3, 'Turkey', Decimal('581.67')),
#  (3, 'Turkmenistan', Decimal('53.92')),
#  (3, 'Tuvalu', Decimal('32.91')),
#  (3, 'Ukraine', Decimal('247.44')),
#  (3, 'United Arab Emirates', Decimal('89.77')),
#  (3, 'United Kingdom', Decimal('276.28')),
#  (3, 'United States', Decimal('1519.45')),
#  (3, 'Venezuela', Decimal('219.45')),
#  (3, 'Vietnam', Decimal('278.35')),
#  (3, 'Virgin Islands, U.S.', Decimal('25.94')),
#  (3, 'Yemen', Decimal('158.65')),
#  (3, 'Yugoslavia', Decimal('73.84')),
#  (3, 'Zambia', Decimal('47.91')),
#  (3, None, Decimal('23886.56')),
#  (4, 'Afghanistan', Decimal('37.92')),
#  (4, 'Algeria', Decimal('170.60')),
#  (4, 'American Samoa', Decimal('39.89')),
#  (4, 'Angola', Decimal('83.80')),
#  (4, 'Anguilla', Decimal('37.86')),
#  (4, 'Argentina', Decimal('650.40')),
#  (4, 'Armenia', Decimal('70.85')),
#  (4, 'Austria', Decimal('117.71')),
#  (4, 'Azerbaijan', Decimal('109.75')),
#  (4, 'Bahrain', Decimal('56.86')),
#  (4, 'Bangladesh', Decimal('163.61')),
#  (4, 'Belarus', Decimal('120.73')),
#  (4, 'Bolivia', Decimal('63.86')),
#  (4, 'Brazil', Decimal('1405.79')),
#  (4, 'Brunei', Decimal('59.81')),
#  (4, 'Bulgaria', Decimal('71.84')),
#  (4, 'Cambodia', Decimal('101.76')),
#  (4, 'Cameroon', Decimal('73.81')),
#  (4, 'Canada', Decimal('220.44')),
#  (4, 'Chad', Decimal('48.89')),
#  (4, 'Chile', Decimal('101.77')),
#  (4, 'China', Decimal('2404.99')),
#  (4, 'Colombia', Decimal('321.28')),
#  (4, 'Congo, The Democratic Republic of the', Decimal('44.90')),
#  (4, 'Czech Republic', Decimal('70.84')),
#  (4, 'Dominican Republic', Decimal('135.70')),
#  (4, 'Ecuador', Decimal('166.61')),
#  (4, 'Egypt', Decimal('281.35')),
#  (4, 'Estonia', Decimal('27.92')),
#  (4, 'Ethiopia', Decimal('23.92')),
#  (4, 'Faroe Islands', Decimal('50.88')),
#  (4, 'Finland', Decimal('32.90')),
#  (4, 'France', Decimal('199.55')),
#  (4, 'French Guiana', Decimal('37.91')),
#  (4, 'French Polynesia', Decimal('85.79')),
#  (4, 'Gambia', Decimal('44.88')),
#  (4, 'Germany', Decimal('326.21')),
#  (4, 'Greece', Decimal('90.81')),
#  (4, 'Greenland', Decimal('58.85')),
#  (4, 'Holy See (Vatican City State)', Decimal('46.87')),
#  (4, 'Hong Kong', Decimal('49.88')),
#  (4, 'Hungary', Decimal('61.85')),
#  (4, 'India', Decimal('2757.46')),
#  (4, 'Indonesia', Decimal('606.61')),
#  (4, 'Iran', Decimal('410.05')),
#  (4, 'Iraq', Decimal('65.86')),
#  (4, 'Israel', Decimal('203.54')),
#  (4, 'Italy', Decimal('339.22')),
#  (4, 'Japan', Decimal('1418.62')),
#  (4, 'Kazakstan', Decimal('96.76')),
#  (4, 'Kenya', Decimal('97.79')),
#  (4, 'Kuwait', Decimal('14.97')),
#  (4, 'Latvia', Decimal('126.70')),
#  (4, 'Liechtenstein', Decimal('49.85')),
#  (4, 'Lithuania', Decimal('26.90')),
#  (4, 'Madagascar', Decimal('23.94')),
#  (4, 'Malawi', Decimal('56.87')),
#  (4, 'Malaysia', Decimal('133.67')),
#  (4, 'Mexico', Decimal('1386.79')),
#  (4, 'Moldova', Decimal('65.82')),
#  (4, 'Morocco', Decimal('100.74')),
#  (4, 'Mozambique', Decimal('195.56')),
#  (4, 'Myanmar', Decimal('34.89')),
#  (4, 'Nauru', Decimal('60.87')),
#  (4, 'Nepal', Decimal('50.90')),
#  (4, 'Netherlands', Decimal('236.44')),
#  (4, 'New Zealand', Decimal('35.88')),
#  (4, 'Nigeria', Decimal('647.43')),
#  (4, 'North Korea', Decimal('57.82')),
#  (4, 'Oman', Decimal('80.76')),
#  (4, 'Pakistan', Decimal('183.53')),
#  (4, 'Paraguay', Decimal('146.72')),
#  (4, 'Peru', Decimal('177.54')),
#  (4, 'Philippines', Decimal('928.65')),
#  (4, 'Poland', Decimal('389.12')),
#  (4, 'Puerto Rico', Decimal('134.68')),
#  (4, 'Romania', Decimal('119.69')),
#  (4, 'Runion', Decimal('100.78')),
#  (4, 'Russian Federation', Decimal('1426.89')),
#  (4, 'Saint Vincent and the Grenadines', Decimal('46.88')),
#  (4, 'Saudi Arabia', Decimal('236.49')),
#  (4, 'Senegal', Decimal('24.93')),
#  (4, 'Slovakia', Decimal('42.88')),
#  (4, 'South Africa', Decimal('467.84')),
#  (4, 'South Korea', Decimal('291.31')),
#  (4, 'Spain', Decimal('257.41')),
#  (4, 'Sri Lanka', Decimal('45.88')),
#  (4, 'Sudan', Decimal('105.76')),
#  (4, 'Sweden', Decimal('60.87')),
#  (4, 'Switzerland', Decimal('140.68')),
#  (4, 'Taiwan', Decimal('565.63')),
#  (4, 'Tanzania', Decimal('145.68')),
#  (4, 'Thailand', Decimal('183.58')),
#  (4, 'Tonga', Decimal('28.94')),
#  (4, 'Tunisia', Decimal('55.85')),
#  (4, 'Turkey', Decimal('742.27')),
#  (4, 'Turkmenistan', Decimal('37.90')),
#  (4, 'Tuvalu', Decimal('48.90')),
#  (4, 'Ukraine', Decimal('348.29')),
#  (4, 'United Arab Emirates', Decimal('161.62')),
#  (4, 'United Kingdom', Decimal('380.10')),
#  (4, 'United States', Decimal('1662.20')),
#  (4, 'Venezuela', Decimal('292.27')),
#  (4, 'Vietnam', Decimal('308.31')),
#  (4, 'Virgin Islands, U.S.', Decimal('68.82')),
#  (4, 'Yemen', Decimal('262.43')),
#  (4, 'Yugoslavia', Decimal('128.73')),
#  (4, 'Zambia', Decimal('54.86')),
#  (4, None, Decimal('28559.46')),
#  (5, 'Algeria', Decimal('5.98')),
#  (5, 'Argentina', Decimal('26.91')),
#  (5, 'Armenia', Decimal('2.99')),
#  (5, 'Azerbaijan', Decimal('0.99')),
#  (5, 'Bahrain', Decimal('2.99')),
#  (5, 'Bangladesh', Decimal('2.99')),
#  (5, 'Belarus', Decimal('2.99')),
#  (5, 'Bolivia', Decimal('2.99')),
#  (5, 'Brazil', Decimal('22.93')),
#  (5, 'Brunei', Decimal('4.99')),
#  (5, 'Bulgaria', Decimal('0.99')),
#  (5, 'Cambodia', Decimal('9.96')),
#  (5, 'Cameroon', Decimal('6.97')),
#  (5, 'Canada', Decimal('3.98')),
#  (5, 'China', Decimal('40.87')),
#  (5, 'Colombia', Decimal('14.97')),
#  (5, 'Faroe Islands', Decimal('0.99')),
#  (5, 'France', Decimal('0.99')),
#  (5, 'French Polynesia', Decimal('8.97')),
#  (5, 'Germany', Decimal('14.95')),
#  (5, 'Greece', Decimal('0.99')),
#  (5, 'Hungary', Decimal('0.99')),
#  (5, 'India', Decimal('62.77')),
#  (5, 'Indonesia', Decimal('5.98')),
#  (5, 'Iran', Decimal('4.99')),
#  (5, 'Iraq', Decimal('0.99')),
#  (5, 'Israel', Decimal('2.99')),
#  (5, 'Italy', Decimal('3.98')),
#  (5, 'Japan', Decimal('22.91')),
#  (5, 'Kenya', Decimal('2.99')),
#  (5, 'Kuwait', Decimal('0.99')),
#  (5, 'Latvia', Decimal('2.99')),
#  (5, 'Lithuania', Decimal('4.99')),
#  (5, 'Malaysia', Decimal('0.99')),
#  (5, 'Mexico', Decimal('13.94')),
#  (5, 'Morocco', Decimal('4.99')),
#  (5, 'Netherlands', Decimal('0.99')),
#  (5, 'Nigeria', Decimal('8.97')),
#  (5, 'Oman', Decimal('4.99')),
#  (5, 'Peru', Decimal('4.99')),
#  (5, 'Philippines', Decimal('25.90')),
#  (5, 'Puerto Rico', Decimal('0.99')),
#  (5, 'Russian Federation', Decimal('7.96')),
#  (5, 'Saudi Arabia', Decimal('3.98')),
#  (5, 'South Africa', Decimal('4.99')),
#  (5, 'South Korea', Decimal('3.98')),
#  (5, 'Spain', Decimal('9.98')),
#  (5, 'Switzerland', Decimal('7.98')),
#  (5, 'Taiwan', Decimal('18.93')),
#  (5, 'Tanzania', Decimal('4.99')),
#  (5, 'Thailand', Decimal('5.98')),
#  (5, 'Tunisia', Decimal('0.99')),
#  (5, 'Turkey', Decimal('10.97')),
#  (5, 'Turkmenistan', Decimal('2.99')),
#  (5, 'United Arab Emirates', Decimal('4.99')),
#  (5, 'United Kingdom', Decimal('11.96')),
#  (5, 'United States', Decimal('28.89')),
#  (5, 'Venezuela', Decimal('5.98')),
#  (5, 'Vietnam', Decimal('8.97')),
#  (5, 'Yemen', Decimal('2.99')),
#  (5, 'Zambia', Decimal('0.99')),
#  (5, None, Decimal('514.18')),
#  (None, None, Decimal('67416.51')),
#  (None, 'Afghanistan', Decimal('67.82')),
#  (None, 'Algeria', Decimal('383.10')),
#  (None, 'American Samoa', Decimal('71.80')),
#  (None, 'Angola', Decimal('215.48')),
#  (None, 'Anguilla', Decimal('106.65')),
#  (None, 'Argentina', Decimal('1434.48')),
#  (None, 'Armenia', Decimal('118.75')),
#  (None, 'Austria', Decimal('307.22')),
#  (None, 'Azerbaijan', Decimal('245.43')),
#  (None, 'Bahrain', Decimal('112.75')),
#  (None, 'Bangladesh', Decimal('402.05')),
#  (None, 'Belarus', Decimal('277.34')),
#  (None, 'Bolivia', Decimal('183.53')),
#  (None, 'Brazil', Decimal('3200.52')),
#  (None, 'Brunei', Decimal('113.65')),
#  (None, 'Bulgaria', Decimal('204.50')),
#  (None, 'Cambodia', Decimal('191.47')),
#  (None, 'Cameroon', Decimal('200.46')),
#  (None, 'Canada', Decimal('593.63')),
#  (None, 'Chad', Decimal('135.68')),
#  (None, 'Chile', Decimal('328.29')),
#  (None, 'China', Decimal('5802.73')),
#  (None, 'Colombia', Decimal('709.41')),
#  (None, 'Congo, The Democratic Republic of the', Decimal('212.50')),
#  (None, 'Czech Republic', Decimal('133.71')),
#  (None, 'Dominican Republic', Decimal('318.23')),
#  (None, 'Ecuador', Decimal('390.13')),
#  (None, 'Egypt', Decimal('694.39')),
#  (None, 'Estonia', Decimal('115.70')),
#  (None, 'Ethiopia', Decimal('91.77')),
#  (None, 'Faroe Islands', Decimal('114.72')),
#  (None, 'Finland', Decimal('101.74')),
#  (None, 'France', Decimal('374.04')),
#  (None, 'French Guiana', Decimal('103.78')),
#  (None, 'French Polynesia', Decimal('235.46')),
#  (None, 'Gambia', Decimal('129.70')),
#  (None, 'Germany', Decimal('831.04')),
#  (None, 'Greece', Decimal('232.46')),
#  (None, 'Greenland', Decimal('137.66')),
#  (None, 'Holy See (Vatican City State)', Decimal('152.66')),
#  (None, 'Hong Kong', Decimal('142.70')),
#  (None, 'Hungary', Decimal('111.71')),
#  (None, 'India', Decimal('6630.27')),
#  (None, 'Indonesia', Decimal('1510.33')),
#  (None, 'Iran', Decimal('950.75')),
#  (None, 'Iraq', Decimal('111.73')),
#  (None, 'Israel', Decimal('422.01')),
#  (None, 'Italy', Decimal('831.11')),
#  (None, 'Japan', Decimal('3471.74')),
#  (None, 'Kazakstan', Decimal('198.48')),
#  (None, 'Kenya', Decimal('253.46')),
#  (None, 'Kuwait', Decimal('111.74')),
#  (None, 'Latvia', Decimal('262.40')),
#  (None, 'Liechtenstein', Decimal('114.72')),
#  (None, 'Lithuania', Decimal('73.76')),
#  (None, 'Madagascar', Decimal('93.78')),
#  (None, 'Malawi', Decimal('123.72')),
#  (None, 'Malaysia', Decimal('369.15')),
#  (None, 'Mexico', Decimal('3307.04')),
#  (None, 'Moldova', Decimal('127.66')),
#  (None, 'Morocco', Decimal('307.29')),
#  (None, 'Mozambique', Decimal('344.20')),
#  (None, 'Myanmar', Decimal('194.48')),
#  (None, 'Nauru', Decimal('148.69')),
#  (None, 'Nepal', Decimal('116.78')),
#  (None, 'Netherlands', Decimal('586.66')),
#  (None, 'New Zealand', Decimal('92.76')),
#  (None, 'Nigeria', Decimal('1511.48')),
#  (None, 'North Korea', Decimal('113.69')),
#  (None, 'Oman', Decimal('187.50')),
#  (None, 'Pakistan', Decimal('525.72')),
#  (None, 'Paraguay', Decimal('275.38')),
#  (None, 'Peru', Decimal('468.88')),
#  (None, 'Philippines', Decimal('2381.32')),
#  (None, 'Poland', Decimal('877.97')),
#  (None, 'Puerto Rico', Decimal('254.39')),
#  (None, 'Romania', Decimal('235.38')),
#  (None, 'Runion', Decimal('216.54')),
#  (None, 'Russian Federation', Decimal('3045.87')),
#  (None, 'Saint Vincent and the Grenadines', Decimal('96.75')),
#  (None, 'Saudi Arabia', Decimal('523.79')),
#  (None, 'Senegal', Decimal('100.75')),
#  (None, 'Slovakia', Decimal('89.74')),
#  (None, 'South Africa', Decimal('1204.15')),
#  (None, 'South Korea', Decimal('574.65')),
#  (None, 'Spain', Decimal('606.58')),
#  (None, 'Sri Lanka', Decimal('116.70')),
#  (None, 'Sudan', Decimal('227.46')),
#  (None, 'Sweden', Decimal('144.66')),
#  (None, 'Switzerland', Decimal('252.39')),
#  (None, 'Taiwan', Decimal('1210.94')),
#  (None, 'Tanzania', Decimal('341.17')),
#  (None, 'Thailand', Decimal('419.04')),
#  (None, 'Tonga', Decimal('73.82')),
#  (None, 'Tunisia', Decimal('78.77')),
#  (None, 'Turkey', Decimal('1662.12')),
#  (None, 'Turkmenistan', Decimal('136.73')),
#  (None, 'Tuvalu', Decimal('120.74')),
#  (None, 'Ukraine', Decimal('730.42')),
#  (None, 'United Arab Emirates', Decimal('333.16')),
#  (None, 'United Kingdom', Decimal('924.80')),
#  (None, 'United States', Decimal('4110.32')),
#  (None, 'Venezuela', Decimal('683.30')),
#  (None, 'Vietnam', Decimal('746.28')),
#  (None, 'Virgin Islands, U.S.', Decimal('122.68')),
#  (None, 'Yemen', Decimal('510.83')),
#  (None, 'Yugoslavia', Decimal('259.43')),
#  (None, 'Zambia', Decimal('134.67'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>None</td>
#         <td>4824.43</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>None</td>
#         <td>9631.88</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Canada</td>
#         <td>11826.23</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>None</td>
#         <td>23886.56</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Australia</td>
#         <td>14136.07</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Canada</td>
#         <td>14423.39</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>None</td>
#         <td>28559.46</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Australia</td>
#         <td>271.08</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Canada</td>
#         <td>243.10</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>None</td>
#         <td>514.18</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>None</td>
#         <td>67416.51</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Australia</td>
#         <td>33726.77</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Canada</td>
#         <td>33689.74</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Revenue Total, by Month, by Country, by Month & Country All in one shot, NAIVE way
# The naive way to create the same table as above is to write several queries and UNION them together. Grouping sets and cubes produce queries that are shorter to write, easier to read, and more performant. Run the naive query below and compare the time it takes to run to the time it takes the cube query to run.

# %%
# %%time
# %%sql
SELECT  NULL as month, NULL as country, sum(sales_amount) as revenue
FROM factSales
    UNION all 
SELECT NULL, dimStore.country,sum(sales_amount) as revenue
FROM factSales
JOIN dimStore on (dimStore.store_key = factSales.store_key)
GROUP by  dimStore.country
    UNION all 
SELECT cast(dimDate.month as text) , NULL, sum(sales_amount) as revenue
FROM factSales
JOIN dimDate on (dimDate.date_key = factSales.date_key)
GROUP by dimDate.month
    UNION all
SELECT cast(dimDate.month as text),dimStore.country,sum(sales_amount) as revenue
FROM factSales
JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
JOIN dimStore on (dimStore.store_key = factSales.store_key)
GROUP by (dimDate.month, dimStore.country)
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 18 rows affected.
# CPU times: user 7.92 ms, sys: 0 ns, total: 7.92 ms
# Wall time: 43.2 ms
# [(None, None, Decimal('67416.51')),
#  (None, 'Australia', Decimal('33726.77')),
#  (None, 'Canada', Decimal('33689.74')),
#  ('1', None, Decimal('4824.43')),
#  ('3', None, Decimal('23886.56')),
#  ('4', None, Decimal('28559.46')),
#  ('2', None, Decimal('9631.88')),
#  ('5', None, Decimal('514.18')),
#  ('4', 'Canada', Decimal('14423.39')),
#  ('3', 'Australia', Decimal('12060.33')),
#  ('5', 'Canada', Decimal('243.10')),
#  ('1', 'Australia', Decimal('2364.19')),
#  ('2', 'Canada', Decimal('4736.78')),
#  ('2', 'Australia', Decimal('4895.10')),
#  ('1', 'Canada', Decimal('2460.24')),
#  ('5', 'Australia', Decimal('271.08')),
#  ('3', 'Canada', Decimal('11826.23')),
#  ('4', 'Australia', Decimal('14136.07'))]
